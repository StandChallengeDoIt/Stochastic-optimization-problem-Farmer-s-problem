# %% [markdown]
# # Homework 2: Stochasic Financial problem resolution and simulation

# %% [markdown]
# ### Solution and simulation for 8 scenarios

# %%
from timeit import default_timer as timer
import pulp
import random
start = timer()
# Definition of the number of scenarios
num_scenarios_S = 8

# Let's define the problem as a maximisation problem
prob = pulp.LpProblem("Stocastic_Financial_planning", pulp.LpMaximize)

# Definition of the decision variables
x = {}  # Investment in stocks and bonds
w = {}  # Borrowing money after 15 years
y = {}  # Wealth after 15 years

for s in range(num_scenarios_S):
    for t in range(1, 4):  # 3 investments periods are considered
        x[1, t, s] = pulp.LpVariable(f"stock_invest_{t}_{s}", lowBound=0)
        x[2, t, s] = pulp.LpVariable(f"bonds_invet_{t}_{s}", lowBound=0)
    w[s] = pulp.LpVariable(f"borrow_{s}", lowBound=0)
    y[s] = pulp.LpVariable(f"wealth_{s}", lowBound=0)

# Define the objective function
q = 0.01  # 1% return on excess
r = 0.04  # 4% cost of borrowing
G = 80000  # Tuition goal


objective = pulp.LpAffineExpression()
for s in range(num_scenarios_S):
    objective += (1/num_scenarios_S)*(q*y[s] - r * w[s])  # Expected utility

prob += objective

# Definition of the constraints
b = 55000  # Initial money to invest
for s in range(num_scenarios_S):
    prob += sum(x[i, 1, s] for i in [1, 2]) == b

    
# The return is randomly taken bwteen 1.01 and 1.5
for s in range(num_scenarios_S):
    for t in range(2, 4):
        prob += (
            sum(x[i, t - 1, s] *random.uniform(1.01, 1.5) for i in [1, 2])- sum(x[i, t, s] for i in [1, 2]) == 0
        )

for s in range(num_scenarios_S):
    prob += (
        sum(x[i, 3, s] *random.uniform(1.01, 1.5) for i in [1, 2]) - y[s] + w[s] == G
    )

# Solving the problem
prob.solve()

# Printing the results
for s in range(num_scenarios_S):
    print(f"Scenario {s+1}:")
    for t in range(1, 4):
        print(f"Investment in Stocks at Period {t}: {pulp.value(x[1, t, s])}")
        print(f"Investment in Bonds at Period {t}: {pulp.value(x[2, t, s])}")
    print(f"Wealth after 15 years: {pulp.value(w[s])}")
    print(f"Borrowing after 15 years: {pulp.value(y[s])}\n")

print(f"Total Expected Utility: {pulp.value(prob.objective)}")
end = timer()
print(f"Time duration for {num_scenarios_S} scenarios is: {end - start}")
# Out:
# Scenario 1:
# Investment in Stocks at Period 1: 1.4551915e-11
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73085.092
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 106678.24
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57568.918
#
# Scenario 2:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 67718.044
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 88272.799
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 51986.909
#
# Scenario 3:
# Investment in Stocks at Period 1: -5.0931703e-11
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75327.361
# Investment in Stocks at Period 3: 80194.857
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 34735.352
#
# Scenario 4:
# Investment in Stocks at Period 1: 7.2759576e-12
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 77795.479
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84386.978
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 28146.143
#
# Scenario 5:
# Investment in Stocks at Period 1: 1.4551915e-11
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 69665.864
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 102752.27
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54809.704
#
# Scenario 6:
# Investment in Stocks at Period 1: 1.4551915e-11
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 75805.737
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 100432.83
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53589.902
#
# Scenario 7:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79273.313
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 97418.113
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62897.596
#
# Scenario 8:
# Investment in Stocks at Period 1: -1.4551915e-11
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 65748.945
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 80648.917
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 12340.257
#
# Total Expected Utility: 445.09347625
# Time duration for 8 scenarios is: 0.028054799999999602

# %% [markdown]
# ### Solution and simulation for 24 scenarios

# %%
from timeit import default_timer as timer
import pulp
import random
start = timer()
# Definition of the number of scenarios
num_scenarios_S = 24

# Let's define the problem as a maximisation problem
prob = pulp.LpProblem("Stocastic_Financial_planning", pulp.LpMaximize)

# Definition of the decision variables
x = {}  # Investment in stocks and bonds
w = {}  # Borrowing money after 15 years
y = {}  # Wealth after 15 years

for s in range(num_scenarios_S):
    for t in range(1, 4):  # 3 investments periods are considered
        x[1, t, s] = pulp.LpVariable(f"stock_invest_{t}_{s}", lowBound=0)
        x[2, t, s] = pulp.LpVariable(f"bonds_invet_{t}_{s}", lowBound=0)
    w[s] = pulp.LpVariable(f"borrow_{s}", lowBound=0)
    y[s] = pulp.LpVariable(f"wealth_{s}", lowBound=0)

# Define the objective function
q = 0.01  # 1% return on excess
r = 0.04  # 4% cost of borrowing
G = 80000  # Tuition goal


objective = pulp.LpAffineExpression()
for s in range(num_scenarios_S):
    objective += (1/num_scenarios_S)*(q*y[s] - r * w[s])  # Expected utility

prob += objective

# Definition of the constraints
b = 55000  # Initial money to invest
for s in range(num_scenarios_S):
    prob += sum(x[i, 1, s] for i in [1, 2]) == b

    
# The return is randomly taken bwteen 1.01 and 1.5
for s in range(num_scenarios_S):
    for t in range(2, 4):
        prob += (
            sum(x[i, t - 1, s] *random.uniform(1.01, 1.5) for i in [1, 2])- sum(x[i, t, s] for i in [1, 2]) == 0
        )

for s in range(num_scenarios_S):
    prob += (
        sum(x[i, 3, s] *random.uniform(1.01, 1.5) for i in [1, 2]) - y[s] + w[s] == G
    )

# Solving the problem
prob.solve()

# Printing the results
for s in range(num_scenarios_S):
    print(f"Scenario {s+1}:")
    for t in range(1, 4):
        print(f"Investment in Stocks at Period {t}: {pulp.value(x[1, t, s])}")
        print(f"Investment in Bonds at Period {t}: {pulp.value(x[2, t, s])}")
    print(f"Wealth after 15 years: {pulp.value(w[s])}")
    print(f"Borrowing after 15 years: {pulp.value(y[s])}\n")

print(f"Total Expected Utility: {pulp.value(prob.objective)}")
end = timer()
print(f"Time duration for {num_scenarios_S} scenarios is: {end - start}")
# Out:
# Scenario 1:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 68831.148
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 79402.26
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 18528.553
#
# Scenario 2:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 78190.568
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 82249.198
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 29104.867
#
# Scenario 3:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 70355.129
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 99382.862
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45619.503
#
# Scenario 4:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79999.708
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 119393.25
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62527.019
#
# Scenario 5:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78996.649
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 115057.07
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 83640.662
#
# Scenario 6:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80974.872
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 90946.643
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 38804.993
#
# Scenario 7:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81938.547
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 118731.1
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 80311.711
#
# Scenario 8:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82381.203
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 92759.112
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 36659.258
#
# Scenario 9:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76164.501
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 109999.66
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 71269.732
#
# Scenario 10:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 64085.669
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 73422.27
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17601.271
#
# Scenario 11:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81460.277
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 120395.32
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 99566.438
#
# Scenario 12:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72397.062
# Investment in Stocks at Period 3: 100514.34
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70748.466
#
# Scenario 13:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77208.71
# Investment in Stocks at Period 3: 109404.48
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 35230.222
#
# Scenario 14:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72871.12
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 98720.213
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 29427.124
#
# Scenario 15:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 82158.49
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 97789.328
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48149.97
#
# Scenario 16:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78801.216
# Investment in Stocks at Period 3: 103786.44
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58257.937
#
# Scenario 17:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 55791.532
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 67084.753
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 11619.969
#
# Scenario 18:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 66433.367
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 94088.526
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48236.625
#
# Scenario 19:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 80933.267
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 118434.56
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 79961.141
#
# Scenario 20:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 77265.569
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97320.955
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 28624.948
#
# Scenario 21:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 79533.102
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 106193.33
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69205.124
#
# Scenario 22:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76114.275
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 88549.575
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 49958.363
#
# Scenario 23:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80339.39
# Investment in Stocks at Period 3: 108605.79
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 73966.35
#
# Scenario 24:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 57837.771
# Investment in Stocks at Period 3: 85354.121
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 30998.25
#
# Total Expected Utility: 507.5077066666666
# Time duration for 24 scenarios is: 0.038136100000087936

# %% [markdown]
# ### Solution and simulation for 50 scenarios

# %%
from timeit import default_timer as timer
import pulp
import random
start = timer()
# Definition of the number of scenarios
num_scenarios_S = 50

# Let's define the problem as a maximisation problem
prob = pulp.LpProblem("Stocastic_Financial_planning", pulp.LpMaximize)

# Definition of the decision variables
x = {}  # Investment in stocks and bonds
w = {}  # Borrowing money after 15 years
y = {}  # Wealth after 15 years

for s in range(num_scenarios_S):
    for t in range(1, 4):  # 3 investments periods are considered
        x[1, t, s] = pulp.LpVariable(f"stock_invest_{t}_{s}", lowBound=0)
        x[2, t, s] = pulp.LpVariable(f"bonds_invet_{t}_{s}", lowBound=0)
    w[s] = pulp.LpVariable(f"borrow_{s}", lowBound=0)
    y[s] = pulp.LpVariable(f"wealth_{s}", lowBound=0)

# Define the objective function
q = 0.01  # 1% return on excess
r = 0.04  # 4% cost of borrowing
G = 80000  # Tuition goal


objective = pulp.LpAffineExpression()
for s in range(num_scenarios_S):
    objective += (1/num_scenarios_S)*(q*y[s] - r * w[s])  # Expected utility

prob += objective

# Definition of the constraints
b = 55000  # Initial money to invest
for s in range(num_scenarios_S):
    prob += sum(x[i, 1, s] for i in [1, 2]) == b

    
# The return is randomly taken bwteen 1.01 and 1.5
for s in range(num_scenarios_S):
    for t in range(2, 4):
        prob += (
            sum(x[i, t - 1, s] *random.uniform(1.01, 1.5) for i in [1, 2])- sum(x[i, t, s] for i in [1, 2]) == 0
        )

for s in range(num_scenarios_S):
    prob += (
        sum(x[i, 3, s] *random.uniform(1.01, 1.5) for i in [1, 2]) - y[s] + w[s] == G
    )

# Solving the problem
prob.solve()

# Printing the results
for s in range(num_scenarios_S):
    print(f"Scenario {s+1}:")
    for t in range(1, 4):
        print(f"Investment in Stocks at Period {t}: {pulp.value(x[1, t, s])}")
        print(f"Investment in Bonds at Period {t}: {pulp.value(x[2, t, s])}")
    print(f"Wealth after 15 years: {pulp.value(w[s])}")
    print(f"Borrowing after 15 years: {pulp.value(y[s])}\n")

print(f"Total Expected Utility: {pulp.value(prob.objective)}")
end = timer()
print(f"Time duration for {num_scenarios_S} scenarios is: {end - start}")
# Out:
# Scenario 1:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72368.663
# Investment in Stocks at Period 3: 94054.152
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59759.627
#
# Scenario 2:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 70012.162
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 98064.611
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 55228.923
#
# Scenario 3:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 69076.975
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 91376.233
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 20771.659
#
# Scenario 4:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71003.568
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84319.35
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42671.311
#
# Scenario 5:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 77569.083
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 115838.69
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 76971.939
#
# Scenario 6:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77462.402
# Investment in Stocks at Period 3: 99437.768
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31422.351
#
# Scenario 7:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79736.758
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 103395.6
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 55007.318
#
# Scenario 8:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 68168.958
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100871.17
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53707.501
#
# Scenario 9:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77105.065
# Investment in Stocks at Period 3: 113532.27
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57951.68
#
# Scenario 10:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 75491.17
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 98652.975
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53649.237
#
# Scenario 11:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 61226.315
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 78684.449
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 25678.543
#
# Scenario 12:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71530.208
# Investment in Stocks at Period 3: 100192.0
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65662.16
#
# Scenario 13:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73845.597
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 103006.89
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60908.69
#
# Scenario 14:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74356.365
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 93001.709
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 30843.082
#
# Scenario 15:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 61704.302
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 69052.336
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 16347.492
#
# Scenario 16:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80926.557
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 109995.63
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65519.481
#
# Scenario 17:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70819.877
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 75783.639
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33467.026
#
# Scenario 18:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 69161.11
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 100972.55
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58052.04
#
# Scenario 19:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73605.083
# Investment in Stocks at Period 3: 85832.55
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 22615.05
#
# Scenario 20:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79781.024
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 89186.006
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 50441.165
#
# Scenario 21:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74287.705
# Investment in Stocks at Period 3: 107745.48
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 72857.571
#
# Scenario 22:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81158.91
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95885.877
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53801.273
#
# Scenario 23:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81275.516
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102741.58
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 55542.128
#
# Scenario 24:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 69433.475
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 95515.831
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 55949.837
#
# Scenario 25:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63552.538
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 79627.536
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 24316.348
#
# Scenario 26:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78373.143
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 98665.093
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59305.304
#
# Scenario 27:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78743.932
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 113461.88
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 73600.461
#
# Scenario 28:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 82034.617
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 105658.38
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69830.139
#
# Scenario 29:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80369.987
# Investment in Stocks at Period 3: 107052.1
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57044.613
#
# Scenario 30:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82099.123
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 120784.74
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 86532.783
#
# Scenario 31:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71178.452
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 90453.275
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45893.575
#
# Scenario 32:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 75291.175
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100560.3
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58129.405
#
# Scenario 33:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70322.591
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 74378.597
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 19304.422
#
# Scenario 34:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79697.977
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 112214.33
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56989.652
#
# Scenario 35:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 82459.415
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 122736.59
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56801.613
#
# Scenario 36:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70750.504
# Investment in Stocks at Period 3: 98066.652
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53172.036
#
# Scenario 37:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80964.633
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 120282.5
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 92660.159
#
# Scenario 38:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 78280.871
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 111240.65
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 79301.165
#
# Scenario 39:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 65174.73
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 91401.443
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 32445.608
#
# Scenario 40:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 66408.427
# Investment in Stocks at Period 3: 77497.548
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 5511.7001
#
# Scenario 41:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81362.836
# Investment in Stocks at Period 3: 98585.254
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 32705.107
#
# Scenario 42:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 68827.189
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 89045.824
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 51399.976
#
# Scenario 43:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76837.61
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 108401.49
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52059.22
#
# Scenario 44:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72492.191
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 76330.593
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 29002.336
#
# Scenario 45:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77867.344
# Investment in Stocks at Period 3: 113771.3
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 84166.569
#
# Scenario 46:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78087.843
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 90555.329
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48292.827
#
# Scenario 47:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73710.603
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 93881.023
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 36395.272
#
# Scenario 48:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 82158.117
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 116845.68
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 90317.328
#
# Scenario 49:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 59425.939
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 85425.328
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 16745.52
#
# Scenario 50:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76535.33
# Investment in Stocks at Period 3: 108987.87
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 81503.313
#
# Total Expected Utility: 513.6507070199999
# Time duration for 50 scenarios is: 0.060498400000000174

# %% [markdown]
# ### Solution and simulation for 100 scenarios

# %%
from timeit import default_timer as timer
import pulp
import random
start = timer()
# Definition of the number of scenarios
num_scenarios_S = 100

# Let's define the problem as a maximisation problem
prob = pulp.LpProblem("Stocastic_Financial_planning", pulp.LpMaximize)

# Definition of the decision variables
x = {}  # Investment in stocks and bonds
w = {}  # Borrowing money after 15 years
y = {}  # Wealth after 15 years

for s in range(num_scenarios_S):
    for t in range(1, 4):  # 3 investments periods are considered
        x[1, t, s] = pulp.LpVariable(f"stock_invest_{t}_{s}", lowBound=0)
        x[2, t, s] = pulp.LpVariable(f"bonds_invet_{t}_{s}", lowBound=0)
    w[s] = pulp.LpVariable(f"borrow_{s}", lowBound=0)
    y[s] = pulp.LpVariable(f"wealth_{s}", lowBound=0)

# Define the objective function
q = 0.01  # 1% return on excess
r = 0.04  # 4% cost of borrowing
G = 80000  # Tuition goal


objective = pulp.LpAffineExpression()
for s in range(num_scenarios_S):
    objective += (1/num_scenarios_S)*(q*y[s] - r * w[s])  # Expected utility

prob += objective

# Definition of the constraints
b = 55000  # Initial money to invest
for s in range(num_scenarios_S):
    prob += sum(x[i, 1, s] for i in [1, 2]) == b

    
# The return is randomly taken bwteen 1.01 and 1.5
for s in range(num_scenarios_S):
    for t in range(2, 4):
        prob += (
            sum(x[i, t - 1, s] *random.uniform(1.01, 1.5) for i in [1, 2])- sum(x[i, t, s] for i in [1, 2]) == 0
        )

for s in range(num_scenarios_S):
    prob += (
        sum(x[i, 3, s] *random.uniform(1.01, 1.5) for i in [1, 2]) - y[s] + w[s] == G
    )

# Solving the problem
prob.solve()

# Printing the results
for s in range(num_scenarios_S):
    print(f"Scenario {s+1}:")
    for t in range(1, 4):
        print(f"Investment in Stocks at Period {t}: {pulp.value(x[1, t, s])}")
        print(f"Investment in Bonds at Period {t}: {pulp.value(x[2, t, s])}")
    print(f"Wealth after 15 years: {pulp.value(w[s])}")
    print(f"Borrowing after 15 years: {pulp.value(y[s])}\n")

print(f"Total Expected Utility: {pulp.value(prob.objective)}")
end = timer()
print(f"Time duration for {num_scenarios_S} scenarios is: {end - start}")
# Out:
# Scenario 1:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76248.669
# Investment in Stocks at Period 3: 100102.39
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58803.781
#
# Scenario 2:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82141.848
# Investment in Stocks at Period 3: 117059.53
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 67514.031
#
# Scenario 3:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 72141.701
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 99892.496
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 67184.162
#
# Scenario 4:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 77887.65
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 85584.331
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 26926.885
#
# Scenario 5:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 81524.158
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 111802.86
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 68433.368
#
# Scenario 6:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 81790.645
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 119953.89
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 79776.909
#
# Scenario 7:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 75905.224
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 110815.09
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 64459.216
#
# Scenario 8:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80636.481
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 119085.7
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 92508.44
#
# Scenario 9:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 60262.606
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 72548.219
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 12578.305
#
# Scenario 10:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 67301.689
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 87175.68
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42090.544
#
# Scenario 11:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78595.028
# Investment in Stocks at Period 3: 115049.42
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 84405.77
#
# Scenario 12:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72066.922
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 94969.684
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59916.691
#
# Scenario 13:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 77509.603
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 82996.041
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42034.749
#
# Scenario 14:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79259.478
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 101177.97
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 32578.949
#
# Scenario 15:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76274.823
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 112755.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 72442.834
#
# Scenario 16:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76257.573
# Investment in Stocks at Period 3: 101702.89
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 39897.082
#
# Scenario 17:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 62419.109
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 79159.472
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 26303.082
#
# Scenario 18:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 82351.261
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104541.79
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53829.105
#
# Scenario 19:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73465.001
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 80033.459
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 15224.74
#
# Scenario 20:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 60825.449
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 75108.686
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 27514.805
#
# Scenario 21:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76216.515
# Investment in Stocks at Period 3: 113015.85
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 79029.589
#
# Scenario 22:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72531.637
# Investment in Stocks at Period 3: 92923.342
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48476.668
#
# Scenario 23:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79249.242
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 87144.134
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 43716.4
#
# Scenario 24:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79263.29
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 94063.856
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59081.196
#
# Scenario 25:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75484.166
# Investment in Stocks at Period 3: 96558.387
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 28672.383
#
# Scenario 26:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 75886.133
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 105652.08
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61073.613
#
# Scenario 27:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 82175.344
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 113798.62
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 90655.786
#
# Scenario 28:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 78458.758
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 96082.77
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54704.593
#
# Scenario 29:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 66628.48
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95943.632
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31258.502
#
# Scenario 30:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63708.574
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 92510.97
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45575.128
#
# Scenario 31:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 72992.693
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 103793.7
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60013.292
#
# Scenario 32:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 57343.857
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 73039.095
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 28888.023
#
# Scenario 33:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 66239.773
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 79511.869
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 39144.837
#
# Scenario 34:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72881.27
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 99053.101
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33421.835
#
# Scenario 35:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 62876.568
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 74679.045
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 2672.2757
#
# Scenario 36:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 74032.363
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95338.808
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59103.709
#
# Scenario 37:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75334.152
# Investment in Stocks at Period 3: 107675.61
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56819.056
#
# Scenario 38:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77827.913
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95680.777
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54575.292
#
# Scenario 39:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 67520.46
# Investment in Stocks at Period 3: 78073.792
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33749.979
#
# Scenario 40:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73945.987
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 106355.87
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 76872.051
#
# Scenario 41:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74664.008
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 111150.64
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 74253.722
#
# Scenario 42:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77020.04
# Investment in Stocks at Period 3: 105113.66
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 68326.523
#
# Scenario 43:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81943.289
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 120916.63
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69681.472
#
# Scenario 44:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 80432.909
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 97249.667
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 37086.114
#
# Scenario 45:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 69079.202
# Investment in Stocks at Period 3: 90109.367
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33249.657
#
# Scenario 46:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82475.37
# Investment in Stocks at Period 3: 113812.41
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 86651.835
#
# Scenario 47:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78871.88
# Investment in Stocks at Period 3: 111963.6
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48788.902
#
# Scenario 48:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79122.752
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 113593.75
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 81445.627
#
# Scenario 49:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 81471.364
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 102551.17
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62855.672
#
# Scenario 50:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 67867.618
# Investment in Stocks at Period 3: 87916.873
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 39898.392
#
# Scenario 51:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72422.583
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 101395.31
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56456.71
#
# Scenario 52:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72338.505
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 81667.247
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 23040.954
#
# Scenario 53:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72750.15
# Investment in Stocks at Period 3: 108609.76
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 73334.812
#
# Scenario 54:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 82013.362
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 113544.76
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69561.145
#
# Scenario 55:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71767.862
# Investment in Stocks at Period 3: 88449.909
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 32380.319
#
# Scenario 56:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 71607.966
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 99223.22
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62169.148
#
# Scenario 57:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76650.9
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 101091.82
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 34619.968
#
# Scenario 58:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78602.453
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100009.75
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 23339.412
#
# Scenario 59:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73735.625
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 77117.681
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 30980.628
#
# Scenario 60:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 67714.649
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97335.598
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65034.216
#
# Scenario 61:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 62153.536
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 78872.752
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 18766.628
#
# Scenario 62:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 66993.114
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 98039.475
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 51475.925
#
# Scenario 63:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77770.923
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 108867.43
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 76731.471
#
# Scenario 64:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 68114.587
# Investment in Stocks at Period 3: 97815.71
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60978.862
#
# Scenario 65:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78804.343
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 115165.04
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 79561.688
#
# Scenario 66:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 78907.19
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 110419.39
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 43118.828
#
# Scenario 67:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78966.35
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102806.9
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66585.411
#
# Scenario 68:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79511.519
# Investment in Stocks at Period 3: 116504.04
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66534.227
#
# Scenario 69:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 60277.941
# Investment in Stocks at Period 3: 85354.233
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 34863.822
#
# Scenario 70:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79231.464
# Investment in Stocks at Period 3: 94377.144
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 44974.158
#
# Scenario 71:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63907.147
# Investment in Stocks at Period 3: 77684.506
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 26987.934
#
# Scenario 72:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 68971.109
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100686.23
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70534.984
#
# Scenario 73:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79955.859
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 114840.71
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66261.333
#
# Scenario 74:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75151.307
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 112588.28
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 85461.226
#
# Scenario 75:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 59532.58
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 77507.841
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 32829.354
#
# Scenario 76:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71377.227
# Investment in Stocks at Period 3: 87287.697
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 25648.464
#
# Scenario 77:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 68203.909
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 81221.292
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 32813.115
#
# Scenario 78:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 74440.727
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 108824.7
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 41373.655
#
# Scenario 79:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 57291.367
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 63389.195
# Wealth after 15 years: 7932.4626
# Borrowing after 15 years: 0.0
#
# Scenario 80:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71050.047
# Investment in Stocks at Period 3: 81414.704
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 21042.415
#
# Scenario 81:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 78606.211
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 104355.71
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69156.845
#
# Scenario 82:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75288.221
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 106173.83
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69616.529
#
# Scenario 83:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 61282.749
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 81707.69
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 32059.278
#
# Scenario 84:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 73698.068
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 95474.222
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62023.993
#
# Scenario 85:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80976.401
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 112794.94
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 47589.15
#
# Scenario 86:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78066.244
# Investment in Stocks at Period 3: 107812.7
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 40068.866
#
# Scenario 87:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77330.393
# Investment in Stocks at Period 3: 112019.21
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 75101.033
#
# Scenario 88:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 70777.615
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 87288.089
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 34581.688
#
# Scenario 89:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 78579.085
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 113931.46
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 77167.536
#
# Scenario 90:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81836.94
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 103892.77
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 71120.641
#
# Scenario 91:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 80087.257
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 115592.48
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 75675.789
#
# Scenario 92:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70429.718
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102691.41
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66554.15
#
# Scenario 93:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 70764.017
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 105727.29
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53402.742
#
# Scenario 94:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80366.839
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 111442.48
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 85237.486
#
# Scenario 95:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71753.273
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100291.55
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57582.993
#
# Scenario 96:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 81535.507
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 113368.22
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 83266.591
#
# Scenario 97:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81724.765
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 118976.49
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 96582.883
#
# Scenario 98:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73259.971
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102943.39
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66513.075
#
# Scenario 99:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72523.058
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 107364.66
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65556.849
#
# Scenario 100:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70291.936
# Investment in Stocks at Period 3: 73966.176
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17700.044
#
# Total Expected Utility: 525.6454694299999
# Time duration for 100 scenarios is: 0.11303080000000065

# %% [markdown]
# ### Solution and simulation for 1000 scenarios

# %%
from timeit import default_timer as timer
import pulp
import random
start = timer()
# Definition of the number of scenarios
num_scenarios_S = 1000

# Let's define the problem as a maximisation problem
prob = pulp.LpProblem("Stocastic_Financial_planning", pulp.LpMaximize)

# Definition of the decision variables
x = {}  # Investment in stocks and bonds
w = {}  # Borrowing money after 15 years
y = {}  # Wealth after 15 years

for s in range(num_scenarios_S):
    for t in range(1, 4):  # 3 investments periods are considered
        x[1, t, s] = pulp.LpVariable(f"stock_invest_{t}_{s}", lowBound=0)
        x[2, t, s] = pulp.LpVariable(f"bonds_invet_{t}_{s}", lowBound=0)
    w[s] = pulp.LpVariable(f"borrow_{s}", lowBound=0)
    y[s] = pulp.LpVariable(f"wealth_{s}", lowBound=0)

# Define the objective function
q = 0.01  # 1% return on excess
r = 0.04  # 4% cost of borrowing
G = 80000  # Tuition goal


objective = pulp.LpAffineExpression()
for s in range(num_scenarios_S):
    objective += (1/num_scenarios_S)*(q*y[s] - r * w[s])  # Expected utility

prob += objective

# Definition of the constraints
b = 55000  # Initial money to invest
for s in range(num_scenarios_S):
    prob += sum(x[i, 1, s] for i in [1, 2]) == b

    
# The return is randomly taken bwteen 1.01 and 1.5
for s in range(num_scenarios_S):
    for t in range(2, 4):
        prob += (
            sum(x[i, t - 1, s] *random.uniform(1.01, 1.5) for i in [1, 2])- sum(x[i, t, s] for i in [1, 2]) == 0
        )

for s in range(num_scenarios_S):
    prob += (
        sum(x[i, 3, s] *random.uniform(1.01, 1.5) for i in [1, 2]) - y[s] + w[s] == G
    )

# Solving the problem
prob.solve()

# Printing the results
for s in range(num_scenarios_S):
    print(f"Scenario {s+1}:")
    for t in range(1, 4):
        print(f"Investment in Stocks at Period {t}: {pulp.value(x[1, t, s])}")
        print(f"Investment in Bonds at Period {t}: {pulp.value(x[2, t, s])}")
    print(f"Wealth after 15 years: {pulp.value(w[s])}")
    print(f"Borrowing after 15 years: {pulp.value(y[s])}\n")

print(f"Total Expected Utility: {pulp.value(prob.objective)}")
end = timer()
print(f"Time duration for {num_scenarios_S} scenarios is: {end - start}")
# Out:
# Scenario 1:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 67379.1
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 98856.601
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65415.886
#
# Scenario 2:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 78756.895
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 101089.48
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33983.897
#
# Scenario 3:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72900.342
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84033.219
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 39740.281
#
# Scenario 4:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 69685.188
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97319.76
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 44988.777
#
# Scenario 5:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 73330.477
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 108589.04
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 78753.498
#
# Scenario 6:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80101.754
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 108132.41
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 67686.717
#
# Scenario 7:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 69569.696
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102649.88
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 49566.744
#
# Scenario 8:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 79013.425
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100295.3
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70145.057
#
# Scenario 9:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73913.077
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 95066.83
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61898.172
#
# Scenario 10:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79178.371
# Investment in Stocks at Period 3: 108107.64
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62461.728
#
# Scenario 11:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 68157.101
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 101907.04
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 50554.51
#
# Scenario 12:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 73008.001
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 93756.675
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42650.654
#
# Scenario 13:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77182.895
# Investment in Stocks at Period 3: 101198.55
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54571.349
#
# Scenario 14:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74998.132
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 109422.73
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58380.946
#
# Scenario 15:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78947.84
# Investment in Stocks at Period 3: 113802.42
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 47598.988
#
# Scenario 16:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77200.349
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95379.963
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56797.048
#
# Scenario 17:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 61075.246
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 70431.688
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17644.49
#
# Scenario 18:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 81957.932
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 109058.65
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 81004.986
#
# Scenario 19:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79110.141
# Investment in Stocks at Period 3: 113236.5
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 68524.493
#
# Scenario 20:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 82041.694
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 114055.37
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 90075.785
#
# Scenario 21:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 66905.178
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 72007.67
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17454.861
#
# Scenario 22:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73994.121
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 83557.73
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 25872.11
#
# Scenario 23:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 81188.937
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 93919.455
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53195.939
#
# Scenario 24:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 71798.127
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104625.12
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62139.692
#
# Scenario 25:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 68760.853
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102260.83
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66569.965
#
# Scenario 26:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 71839.386
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104608.15
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 71484.135
#
# Scenario 27:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80876.641
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 110131.76
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 83218.648
#
# Scenario 28:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 77759.373
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 101882.47
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 64069.071
#
# Scenario 29:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73446.019
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 109947.03
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 78174.341
#
# Scenario 30:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 60298.497
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 83461.297
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 34418.259
#
# Scenario 31:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72196.628
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 105582.26
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 76864.781
#
# Scenario 32:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76543.367
# Investment in Stocks at Period 3: 92218.477
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 41305.346
#
# Scenario 33:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 80497.865
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 106036.31
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58665.426
#
# Scenario 34:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79819.411
# Investment in Stocks at Period 3: 113858.57
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 80289.824
#
# Scenario 35:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71804.173
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 87374.492
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31117.508
#
# Scenario 36:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 64002.181
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 85460.973
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 28273.658
#
# Scenario 37:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75455.58
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 112834.44
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 71137.739
#
# Scenario 38:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80344.737
# Investment in Stocks at Period 3: 99412.818
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60026.63
#
# Scenario 39:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 68829.478
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95185.612
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45727.456
#
# Scenario 40:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79922.051
# Investment in Stocks at Period 3: 100530.88
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 39203.244
#
# Scenario 41:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78333.918
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 117352.93
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48911.926
#
# Scenario 42:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 64332.929
# Investment in Stocks at Period 3: 94933.307
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 38448.053
#
# Scenario 43:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63596.966
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 86284.289
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31685.067
#
# Scenario 44:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 74268.748
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 107946.41
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 78245.014
#
# Scenario 45:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70644.71
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97732.76
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53568.883
#
# Scenario 46:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 77465.53
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 108903.83
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52421.47
#
# Scenario 47:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 81342.586
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 120194.57
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 89254.611
#
# Scenario 48:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78003.257
# Investment in Stocks at Period 3: 105778.93
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 47510.075
#
# Scenario 49:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 62575.998
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84732.849
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 39804.252
#
# Scenario 50:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 61531.271
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 86717.503
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 46322.89
#
# Scenario 51:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 72553.854
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 97207.076
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 51867.582
#
# Scenario 52:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75479.763
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 94582.125
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48364.521
#
# Scenario 53:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77935.997
# Investment in Stocks at Period 3: 109347.49
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 35931.114
#
# Scenario 54:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72113.958
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 105716.84
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 50399.985
#
# Scenario 55:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 77626.39
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 100984.05
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54689.556
#
# Scenario 56:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 76700.079
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 113479.27
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53943.724
#
# Scenario 57:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 74957.608
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95243.363
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 38758.707
#
# Scenario 58:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75992.93
# Investment in Stocks at Period 3: 95081.455
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 41571.513
#
# Scenario 59:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 77912.552
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 110627.42
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 75319.735
#
# Scenario 60:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74478.951
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 94854.477
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45801.078
#
# Scenario 61:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72834.608
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 83865.152
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42006.747
#
# Scenario 62:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 68333.485
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 76589.013
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 29385.448
#
# Scenario 63:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 76351.63
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 107809.3
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 71401.9
#
# Scenario 64:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 81424.133
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 96915.277
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65025.833
#
# Scenario 65:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 72845.992
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 93399.09
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 40060.007
#
# Scenario 66:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 61225.264
# Investment in Stocks at Period 3: 88557.538
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 23038.496
#
# Scenario 67:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 63599.468
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 80795.578
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33137.306
#
# Scenario 68:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73542.097
# Investment in Stocks at Period 3: 97648.878
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 35709.033
#
# Scenario 69:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79077.767
# Investment in Stocks at Period 3: 100109.24
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 67418.494
#
# Scenario 70:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 65413.838
# Investment in Stocks at Period 3: 89175.55
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 22830.232
#
# Scenario 71:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 80931.117
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 108038.94
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70950.552
#
# Scenario 72:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 62757.352
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 67895.191
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17843.342
#
# Scenario 73:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 77082.49
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102353.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65822.764
#
# Scenario 74:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80843.973
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 116278.11
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 84899.355
#
# Scenario 75:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76422.515
# Investment in Stocks at Period 3: 113182.73
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 86357.485
#
# Scenario 76:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79708.653
# Investment in Stocks at Period 3: 114956.69
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 88846.422
#
# Scenario 77:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 74600.216
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 106793.84
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66623.841
#
# Scenario 78:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76061.296
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 103103.85
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 68502.612
#
# Scenario 79:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 71207.371
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 105307.31
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70203.427
#
# Scenario 80:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81281.197
# Investment in Stocks at Period 3: 112821.55
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 80574.234
#
# Scenario 81:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 61415.755
# Investment in Stocks at Period 3: 89379.967
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 25340.167
#
# Scenario 82:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 61154.202
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 85693.357
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42283.581
#
# Scenario 83:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75767.368
# Investment in Stocks at Period 3: 103437.11
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65469.625
#
# Scenario 84:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 65140.464
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 88879.174
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 44927.156
#
# Scenario 85:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77780.422
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84901.468
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 22647.33
#
# Scenario 86:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 67838.77
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97130.701
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 41177.211
#
# Scenario 87:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74366.862
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 105222.7
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70011.646
#
# Scenario 88:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 82217.875
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 118297.3
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70947.116
#
# Scenario 89:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 65839.778
# Investment in Stocks at Period 3: 77306.988
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 6913.7924
#
# Scenario 90:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80960.663
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 110350.65
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 84892.207
#
# Scenario 91:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 59891.536
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 78039.58
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 35288.748
#
# Scenario 92:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82077.82
# Investment in Stocks at Period 3: 120858.79
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 80606.28
#
# Scenario 93:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 74956.084
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 106749.24
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 36080.78
#
# Scenario 94:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77755.836
# Investment in Stocks at Period 3: 103201.76
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60093.735
#
# Scenario 95:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 65330.139
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 96237.504
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56682.279
#
# Scenario 96:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 60060.177
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84313.778
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 44796.246
#
# Scenario 97:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77399.477
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97260.027
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57210.349
#
# Scenario 98:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 66572.154
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 85250.476
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 30884.516
#
# Scenario 99:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 73053.301
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 98505.453
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60597.262
#
# Scenario 100:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 61565.06
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 76408.044
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 16237.92
#
# Scenario 101:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77572.13
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 94169.492
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 41806.627
#
# Scenario 102:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76791.356
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 99180.418
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61496.691
#
# Scenario 103:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73085.436
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 106720.65
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 43198.022
#
# Scenario 104:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79340.525
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 108675.18
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61677.231
#
# Scenario 105:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 62472.94
# Investment in Stocks at Period 3: 84600.806
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 39898.832
#
# Scenario 106:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75593.998
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104929.69
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 34361.002
#
# Scenario 107:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 81823.807
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 115082.9
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 90740.406
#
# Scenario 108:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 65748.65
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 80455.55
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17956.115
#
# Scenario 109:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 63787.843
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 75709.226
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 4411.4853
#
# Scenario 110:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 61455.511
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 88263.329
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45554.171
#
# Scenario 111:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 64619.055
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 89997.377
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53953.735
#
# Scenario 112:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 67499.16
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 91453.88
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 50225.106
#
# Scenario 113:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71217.32
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102549.57
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 67473.578
#
# Scenario 114:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 75316.109
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 104637.59
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 55246.292
#
# Scenario 115:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77562.013
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 111637.39
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 85590.44
#
# Scenario 116:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79844.0
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 108542.7
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57298.767
#
# Scenario 117:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80900.853
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 116837.33
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 92759.631
#
# Scenario 118:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76676.013
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 114205.55
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 86052.171
#
# Scenario 119:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 71673.88
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 96145.412
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48406.963
#
# Scenario 120:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77781.23
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 110699.87
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 80946.962
#
# Scenario 121:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75761.156
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 85311.316
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 38556.806
#
# Scenario 122:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72513.597
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84803.495
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 35900.187
#
# Scenario 123:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63767.864
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 77170.968
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 12231.864
#
# Scenario 124:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 69822.533
# Investment in Stocks at Period 3: 97655.781
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 30283.766
#
# Scenario 125:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76220.494
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 103043.39
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62656.842
#
# Scenario 126:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76776.721
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 101775.73
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61768.1
#
# Scenario 127:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81741.489
# Investment in Stocks at Period 3: 117766.29
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52201.56
#
# Scenario 128:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 79450.752
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 115573.05
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62589.707
#
# Scenario 129:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63971.947
# Investment in Stocks at Period 3: 84933.502
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 27955.341
#
# Scenario 130:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75459.342
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 91486.825
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 26210.724
#
# Scenario 131:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 77171.722
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 108553.66
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 77213.229
#
# Scenario 132:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79892.793
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 106315.9
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 63263.545
#
# Scenario 133:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76295.04
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 112134.97
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 55052.406
#
# Scenario 134:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 58688.658
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 87137.507
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 43348.305
#
# Scenario 135:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 59231.504
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 69899.884
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 5161.6753
#
# Scenario 136:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78853.224
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 114103.15
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 88848.468
#
# Scenario 137:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 65197.142
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95068.521
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54170.023
#
# Scenario 138:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 79850.93
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 111009.77
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 72057.997
#
# Scenario 139:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 74135.603
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 97440.815
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 64513.556
#
# Scenario 140:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75536.059
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 92474.359
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52709.044
#
# Scenario 141:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 62964.263
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 86780.408
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 20182.454
#
# Scenario 142:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 62928.905
# Investment in Stocks at Period 3: 84696.671
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 21145.35
#
# Scenario 143:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 65278.246
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 71313.277
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 21612.689
#
# Scenario 144:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 62340.09
# Investment in Stocks at Period 3: 88360.55
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42689.978
#
# Scenario 145:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 78769.512
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 94922.815
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 21868.795
#
# Scenario 146:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 79539.272
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 117541.1
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66068.807
#
# Scenario 147:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 62757.136
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 70148.034
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 10928.281
#
# Scenario 148:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63288.249
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 82938.856
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 29070.0
#
# Scenario 149:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 68706.365
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100536.76
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56682.522
#
# Scenario 150:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 77155.103
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 94633.646
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 47511.62
#
# Scenario 151:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82220.783
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 112401.71
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58050.864
#
# ...
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75596.111
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102256.2
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 72546.763
#
# Scenario 952:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 76457.146
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 105040.08
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62943.227
#
# Scenario 953:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 79899.837
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 81452.893
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 32598.158
#
# Scenario 954:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80846.661
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 108051.95
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 49241.004
#
# Scenario 955:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79049.949
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 117781.85
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 43937.387
#
# Scenario 956:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 57282.177
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 81150.633
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 3282.5297
#
# Scenario 957:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 77778.175
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 108621.48
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 81649.002
#
# Scenario 958:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82194.143
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95661.211
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56184.595
#
# Scenario 959:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 77811.131
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 90856.149
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 47824.446
#
# Scenario 960:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76736.458
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 105610.29
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54335.189
#
# Scenario 961:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 68663.861
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 96479.122
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62902.771
#
# Scenario 962:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72609.75
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 107902.51
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66671.598
#
# Scenario 963:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74018.954
# Investment in Stocks at Period 3: 109502.26
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54818.985
#
# Scenario 964:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 68279.089
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 94353.896
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60079.427
#
# Scenario 965:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72076.055
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104528.23
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57389.367
#
# Scenario 966:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74064.969
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 105833.75
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70549.829
#
# Scenario 967:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 60440.476
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 90476.772
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31363.004
#
# Scenario 968:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77069.628
# Investment in Stocks at Period 3: 107839.73
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 77054.734
#
# Scenario 969:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 75421.024
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 102545.46
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53657.029
#
# Scenario 970:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77121.446
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 110503.68
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48236.579
#
# Scenario 971:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 56493.589
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 83830.23
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 36035.41
#
# Scenario 972:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 74136.412
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 92586.676
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56602.867
#
# Scenario 973:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 80398.608
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 118691.45
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59665.198
#
# Scenario 974:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76922.582
# Investment in Stocks at Period 3: 108724.97
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66787.551
#
# Scenario 975:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 77015.694
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 101184.86
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57818.724
#
# Scenario 976:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76056.149
# Investment in Stocks at Period 3: 111709.41
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66831.044
#
# Scenario 977:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82109.929
# Investment in Stocks at Period 3: 117256.75
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70725.731
#
# Scenario 978:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 71767.173
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 98152.522
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52366.84
#
# Scenario 979:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 57381.072
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 80381.979
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 30472.387
#
# Scenario 980:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 71517.513
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 99044.09
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58327.523
#
# Scenario 981:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76973.772
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 105639.1
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 47463.888
#
# Scenario 982:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 76588.372
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 111124.28
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60443.882
#
# Scenario 983:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 61354.433
# Investment in Stocks at Period 3: 81459.772
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31089.539
#
# Scenario 984:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 78747.3
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 116190.43
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 64190.971
#
# Scenario 985:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 57903.235
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 67676.421
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17019.462
#
# Scenario 986:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74140.44
# Investment in Stocks at Period 3: 90363.192
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 29209.161
#
# Scenario 987:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75509.035
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 110042.17
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 67292.001
#
# Scenario 988:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 81060.535
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 109292.11
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 79202.477
#
# Scenario 989:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75285.862
# Investment in Stocks at Period 3: 95259.658
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 23840.626
#
# Scenario 990:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72721.678
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104668.9
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 49269.051
#
# Scenario 991:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76946.107
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 103707.69
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54930.613
#
# Scenario 992:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 60918.225
# Investment in Stocks at Period 3: 66455.492
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 18700.182
#
# Scenario 993:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63174.635
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 92394.791
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 55721.244
#
# Scenario 994:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79062.865
# Investment in Stocks at Period 3: 118440.43
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62270.969
#
# Scenario 995:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 66273.791
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 74626.305
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31282.612
#
# Scenario 996:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79932.385
# Investment in Stocks at Period 3: 104218.88
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 50988.404
#
# Scenario 997:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75009.241
# Investment in Stocks at Period 3: 92566.047
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52692.249
#
# Scenario 998:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 66203.795
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 90469.739
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 39513.041
#
# Scenario 999:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78060.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 94975.777
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61737.64
#
# Scenario 1000:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78312.323
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 103968.42
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70314.416
#
# Total Expected Utility: 519.199287525
# Time duration for 1000 scenarios is: 0.8552634999999995

# %% [markdown]
# ### Solution and simulation for 3000 scenarios

# %%
from timeit import default_timer as timer
import pulp
import random
start = timer()
# Definition of the number of scenarios
num_scenarios_S = 3000

# Let's define the problem as a maximisation problem
prob = pulp.LpProblem("Stocastic_Financial_planning", pulp.LpMaximize)

# Definition of the decision variables
x = {}  # Investment in stocks and bonds
w = {}  # Borrowing money after 15 years
y = {}  # Wealth after 15 years

for s in range(num_scenarios_S):
    for t in range(1, 4):  # 3 investments periods are considered
        x[1, t, s] = pulp.LpVariable(f"stock_invest_{t}_{s}", lowBound=0)
        x[2, t, s] = pulp.LpVariable(f"bonds_invet_{t}_{s}", lowBound=0)
    w[s] = pulp.LpVariable(f"borrow_{s}", lowBound=0)
    y[s] = pulp.LpVariable(f"wealth_{s}", lowBound=0)

# Define the objective function
q = 0.01  # 1% return on excess
r = 0.04  # 4% cost of borrowing
G = 80000  # Tuition goal


objective = pulp.LpAffineExpression()
for s in range(num_scenarios_S):
    objective += (1/num_scenarios_S)*(q*y[s] - r * w[s])  # Expected utility

prob += objective

# Definition of the constraints
b = 55000  # Initial money to invest
for s in range(num_scenarios_S):
    prob += sum(x[i, 1, s] for i in [1, 2]) == b

    
# The return is randomly taken bwteen 1.01 and 1.5
for s in range(num_scenarios_S):
    for t in range(2, 4):
        prob += (
            sum(x[i, t - 1, s] *random.uniform(1.01, 1.5) for i in [1, 2])- sum(x[i, t, s] for i in [1, 2]) == 0
        )

for s in range(num_scenarios_S):
    prob += (
        sum(x[i, 3, s] *random.uniform(1.01, 1.5) for i in [1, 2]) - y[s] + w[s] == G
    )

# Solving the problem
prob.solve()

# Printing the results
for s in range(num_scenarios_S):
    print(f"Scenario {s+1}:")
    for t in range(1, 4):
        print(f"Investment in Stocks at Period {t}: {pulp.value(x[1, t, s])}")
        print(f"Investment in Bonds at Period {t}: {pulp.value(x[2, t, s])}")
    print(f"Wealth after 15 years: {pulp.value(w[s])}")
    print(f"Borrowing after 15 years: {pulp.value(y[s])}\n")

print(f"Total Expected Utility: {pulp.value(prob.objective)}")
end = timer()
print(f"Time duration for {num_scenarios_S} scenarios is: {end - start}")
# Out:
# Scenario 1:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71330.785
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 106257.8
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66395.763
#
# Scenario 2:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82128.731
# Investment in Stocks at Period 3: 115249.84
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 76142.223
#
# Scenario 3:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 72081.366
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 78594.174
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 10176.591
#
# Scenario 4:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 69308.241
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 76801.277
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 29094.829
#
# Scenario 5:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79921.169
# Investment in Stocks at Period 3: 110231.24
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54312.509
#
# Scenario 6:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81125.035
# Investment in Stocks at Period 3: 114660.3
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 84626.217
#
# Scenario 7:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82277.031
# Investment in Stocks at Period 3: 119805.0
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58126.283
#
# Scenario 8:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 67266.61
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 98356.732
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61471.676
#
# Scenario 9:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63130.259
# Investment in Stocks at Period 3: 88809.18
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42824.662
#
# Scenario 10:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 66995.795
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 96953.129
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 46852.971
#
# Scenario 11:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73868.934
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84122.307
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 20554.916
#
# Scenario 12:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 60038.98
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 85299.0
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 28060.133
#
# Scenario 13:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75130.352
# Investment in Stocks at Period 3: 95219.082
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57686.158
#
# Scenario 14:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79595.204
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 119112.33
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 94090.813
#
# Scenario 15:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77420.812
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97015.135
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52025.34
#
# Scenario 16:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77547.097
# Investment in Stocks at Period 3: 108746.39
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69276.048
#
# Scenario 17:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78035.786
# Investment in Stocks at Period 3: 107339.52
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69205.853
#
# Scenario 18:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76803.479
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 98655.98
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 49928.368
#
# Scenario 19:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 70404.484
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102978.61
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 41456.174
#
# Scenario 20:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 60128.645
# Investment in Stocks at Period 3: 85065.804
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 41093.017
#
# Scenario 21:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75071.743
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 107834.76
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59251.738
#
# Scenario 22:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 73910.755
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104652.58
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62651.861
#
# Scenario 23:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 65687.33
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 88172.694
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 46713.758
#
# Scenario 24:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78937.711
# Investment in Stocks at Period 3: 99552.38
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54045.713
#
# Scenario 25:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 65101.108
# Investment in Stocks at Period 3: 77447.293
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 21224.748
#
# Scenario 26:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 82083.279
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 96868.124
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59193.114
#
# Scenario 27:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73004.671
# Investment in Stocks at Period 3: 108855.86
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 77531.935
#
# Scenario 28:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 69160.127
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97148.577
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53660.156
#
# Scenario 29:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74659.519
# Investment in Stocks at Period 3: 98708.939
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60441.78
#
# Scenario 30:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 82438.339
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 119363.62
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 95802.003
#
# Scenario 31:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78826.448
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 105184.02
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 70680.294
#
# Scenario 32:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77919.025
# Investment in Stocks at Period 3: 103407.77
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31130.006
#
# Scenario 33:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75435.947
# Investment in Stocks at Period 3: 86376.244
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 38503.575
#
# Scenario 34:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 74188.442
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102209.61
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54143.161
#
# Scenario 35:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72234.816
# Investment in Stocks at Period 3: 107393.48
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 74630.128
#
# Scenario 36:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82199.593
# Investment in Stocks at Period 3: 99043.746
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 46427.511
#
# Scenario 37:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 64784.209
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 81195.119
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 24668.295
#
# Scenario 38:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 58176.397
# Investment in Stocks at Period 3: 85710.54
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42142.657
#
# Scenario 39:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72099.532
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104435.65
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42766.72
#
# Scenario 40:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76057.249
# Investment in Stocks at Period 3: 82280.285
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 38423.295
#
# Scenario 41:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73766.618
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102122.58
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 47884.073
#
# Scenario 42:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 63411.193
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 82763.357
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 40856.162
#
# Scenario 43:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 75733.541
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 94086.208
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45257.705
#
# Scenario 44:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77851.487
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100703.2
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 30880.895
#
# Scenario 45:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 79445.665
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 81798.701
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 29789.944
#
# Scenario 46:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 58886.763
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 86169.715
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 28735.634
#
# Scenario 47:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80289.867
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100011.73
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 51477.562
#
# Scenario 48:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 67404.497
# Investment in Stocks at Period 3: 96849.308
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 38999.093
#
# Scenario 49:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73103.682
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 81693.316
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17701.513
#
# Scenario 50:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80032.511
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 116448.41
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 77215.003
#
# Scenario 51:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 64703.609
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 80170.476
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33068.141
#
# Scenario 52:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 82320.79
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 116632.49
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69785.759
#
# Scenario 53:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 82044.266
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 86954.46
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 22255.146
#
# Scenario 54:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74645.59
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97564.193
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66007.651
#
# Scenario 55:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78019.719
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 96043.366
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57112.441
#
# Scenario 56:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78985.217
# Investment in Stocks at Period 3: 101241.24
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 30494.282
#
# Scenario 57:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 68694.982
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 94155.709
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 24345.163
#
# Scenario 58:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71616.421
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 99728.134
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61043.312
#
# Scenario 59:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77725.581
# Investment in Stocks at Period 3: 109300.24
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53566.234
#
# Scenario 60:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80680.023
# Investment in Stocks at Period 3: 118352.12
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 76653.717
#
# Scenario 61:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 58123.95
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 74897.971
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 25668.546
#
# Scenario 62:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74324.346
# Investment in Stocks at Period 3: 105788.42
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 73838.245
#
# Scenario 63:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81926.622
# Investment in Stocks at Period 3: 111389.99
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 76890.47
#
# Scenario 64:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80655.04
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 112096.9
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 85874.324
#
# Scenario 65:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 73734.961
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 79374.075
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 14687.601
#
# Scenario 66:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70121.114
# Investment in Stocks at Period 3: 92655.671
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54902.306
#
# Scenario 67:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 67784.764
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 101582.05
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52609.18
#
# Scenario 68:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 67791.077
# Investment in Stocks at Period 3: 77613.004
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 35805.777
#
# Scenario 69:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 61779.487
# Investment in Stocks at Period 3: 83203.552
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 26237.715
#
# Scenario 70:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80739.714
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 116045.55
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 67552.507
#
# Scenario 71:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 80841.568
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 112514.02
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66609.404
#
# Scenario 72:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 71876.795
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 106174.17
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59806.801
#
# Scenario 73:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71439.689
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104176.5
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 55094.58
#
# Scenario 74:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74959.915
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102349.7
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61989.222
#
# Scenario 75:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63578.041
# Investment in Stocks at Period 3: 72219.559
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 23703.284
#
# Scenario 76:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 60437.905
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 72050.085
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 8047.0832
#
# Scenario 77:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76167.596
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 93562.722
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53478.9
#
# Scenario 78:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79312.019
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 98498.505
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45824.415
#
# Scenario 79:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82121.83
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100653.57
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42942.394
#
# Scenario 80:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 71109.462
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 92335.336
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 30809.841
#
# Scenario 81:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 69795.503
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 104376.8
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52245.784
#
# Scenario 82:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 66118.013
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95267.89
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 47885.759
#
# Scenario 83:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75291.135
# Investment in Stocks at Period 3: 81862.732
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 15956.416
#
# Scenario 84:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 67275.776
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97439.477
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61024.718
#
# Scenario 85:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73979.167
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 109425.15
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65370.079
#
# Scenario 86:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78091.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 116001.45
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 82986.284
#
# Scenario 87:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80111.009
# Investment in Stocks at Period 3: 116971.38
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 85133.109
#
# Scenario 88:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 82331.747
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 92921.86
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 46191.893
#
# Scenario 89:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81163.69
# Investment in Stocks at Period 3: 118965.91
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 90140.08
#
# Scenario 90:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 67227.384
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 89433.737
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 35698.446
#
# Scenario 91:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 64855.681
# Investment in Stocks at Period 3: 94965.563
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57325.219
#
# Scenario 92:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79665.285
# Investment in Stocks at Period 3: 113537.28
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 88327.087
#
# Scenario 93:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 65984.537
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 75879.035
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 20144.245
#
# Scenario 94:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71049.831
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97746.811
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65255.812
#
# Scenario 95:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 68729.331
# Investment in Stocks at Period 3: 95274.24
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58739.231
#
# Scenario 96:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70880.856
# Investment in Stocks at Period 3: 105858.49
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33292.212
#
# Scenario 97:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82326.393
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 112785.42
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57564.272
#
# Scenario 98:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 75359.534
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 111266.46
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 83115.758
#
# Scenario 99:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 68296.29
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 83023.544
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17143.622
#
# Scenario 100:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 72531.871
# Investment in Stocks at Period 3: 92784.471
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 46319.684
#
# Scenario 101:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 82404.983
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 116864.19
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 80096.355
#
# Scenario 102:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78037.481
# Investment in Stocks at Period 3: 106793.08
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62744.176
#
# Scenario 103:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 71733.43
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 95072.415
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 34081.795
#
# Scenario 104:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 67765.494
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 91337.196
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 37704.519
#
# Scenario 105:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82257.586
# Investment in Stocks at Period 3: 104533.83
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 43087.482
#
# Scenario 106:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71729.046
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 91101.488
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 38557.839
#
# Scenario 107:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 63202.112
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 93606.016
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 37975.832
#
# Scenario 108:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70888.471
# Investment in Stocks at Period 3: 102863.57
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61150.279
#
# Scenario 109:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79580.613
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 111996.79
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54375.404
#
# Scenario 110:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 66105.166
# Investment in Stocks at Period 3: 91980.996
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57470.364
#
# Scenario 111:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 67728.098
# Investment in Stocks at Period 3: 95286.502
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 27816.495
#
# Scenario 112:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79165.555
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 109666.51
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66325.536
#
# Scenario 113:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77175.193
# Investment in Stocks at Period 3: 105867.16
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 71991.511
#
# Scenario 114:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73565.062
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 107192.33
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 68431.881
#
# Scenario 115:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 63873.475
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 85225.271
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 34690.864
#
# Scenario 116:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 76523.921
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 90812.818
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56159.267
#
# Scenario 117:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78752.605
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 89923.02
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 28462.405
#
# Scenario 118:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73011.397
# Investment in Stocks at Period 3: 106625.56
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 78646.202
#
# Scenario 119:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77568.502
# Investment in Stocks at Period 3: 97637.117
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53267.838
#
# Scenario 120:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 74172.253
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 106929.52
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 54453.058
#
# Scenario 121:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 68036.417
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 96130.488
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 51571.046
#
# Scenario 122:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76213.247
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 108444.14
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 42647.149
#
# Scenario 123:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 69483.48
# Investment in Stocks at Period 3: 98684.911
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52293.144
#
# Scenario 124:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75330.568
# Investment in Stocks at Period 3: 85238.835
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17025.897
#
# Scenario 125:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 79817.305
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 100174.15
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60549.507
#
# Scenario 126:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70285.821
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 100253.77
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 50415.04
#
# Scenario 127:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 69152.894
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 99766.361
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65870.535
#
# Scenario 128:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 70114.749
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 81734.589
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 41088.644
#
# Scenario 129:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 78762.068
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 113529.46
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 81021.746
#
# Scenario 130:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 61448.662
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 69768.057
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 21709.42
#
# Scenario 131:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 81634.78
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 113260.65
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 71310.759
#
# Scenario 132:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 80089.02
# Investment in Stocks at Period 3: 118687.47
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 84079.633
#
# Scenario 133:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 80244.596
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 118353.02
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 92843.615
#
# Scenario 134:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 82101.477
# Investment in Stocks at Period 3: 105615.45
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 75063.942
#
# Scenario 135:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 74700.886
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 98935.01
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65528.454
#
# Scenario 136:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 70358.662
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 101590.24
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 61919.138
#
# Scenario 137:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 61286.834
# Investment in Stocks at Period 3: 84807.771
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 7176.1157
#
# Scenario 138:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71170.554
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 88425.614
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 28407.355
#
# Scenario 139:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70547.644
# Investment in Stocks at Period 3: 94424.264
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59633.126
#
# Scenario 140:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 69435.725
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 98024.057
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 63223.744
#
# Scenario 141:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70877.811
# Investment in Stocks at Period 3: 94353.594
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45949.065
#
# Scenario 142:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 67696.522
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84058.883
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33470.209
#
# Scenario 143:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75752.84
# Investment in Stocks at Period 3: 92917.895
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58689.646
#
# Scenario 144:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 78212.21
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 110232.26
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 69090.543
#
# Scenario 145:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 69088.456
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 97906.869
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 65060.91
#
# Scenario 146:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 72044.886
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 90796.704
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 35723.879
#
# Scenario 147:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 72656.157
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 98243.261
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57294.543
#
# Scenario 148:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 64904.258
# Investment in Stocks at Period 3: 72266.123
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 27185.509
#
# Scenario 149:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71866.385
# Investment in Stocks at Period 3: 105580.56
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 78284.25
#
# Scenario 150:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74766.32
# Investment in Stocks at Period 3: 99399.157
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 51626.118
#
# Scenario 151:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 70980.638
# Investment in Stocks at Period 3: 97787.76
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# ...
# Investment in Stocks at Period 2: 81134.664
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 101552.67
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 66391.038
#
# Scenario 2952:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 70253.862
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 93012.487
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56197.639
#
# Scenario 2953:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79742.633
# Investment in Stocks at Period 3: 99279.26
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 52936.749
#
# Scenario 2954:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73507.801
# Investment in Stocks at Period 3: 93032.702
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 37800.123
#
# Scenario 2955:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 66365.168
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84431.387
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 41829.593
#
# Scenario 2956:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 79626.959
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 117549.21
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 84152.433
#
# Scenario 2957:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74492.416
# Investment in Stocks at Period 3: 83744.367
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45301.583
#
# Scenario 2958:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 64323.256
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 93206.269
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 55571.967
#
# Scenario 2959:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75671.958
# Investment in Stocks at Period 3: 86987.229
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 37544.394
#
# Scenario 2960:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 63647.172
# Investment in Stocks at Period 3: 84417.086
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 36001.473
#
# Scenario 2961:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 74730.337
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 110778.11
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 84420.415
#
# Scenario 2962:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76306.922
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 108568.27
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 50858.894
#
# Scenario 2963:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 78518.563
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 87987.707
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 49823.388
#
# Scenario 2964:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78033.897
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 101610.29
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62246.865
#
# Scenario 2965:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 76244.088
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 96313.56
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 63711.391
#
# Scenario 2966:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 62261.302
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 88842.383
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 51139.214
#
# Scenario 2967:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 78530.029
# Investment in Stocks at Period 3: 112184.2
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 73531.365
#
# Scenario 2968:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 72590.23
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 104177.99
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56906.741
#
# Scenario 2969:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 68083.214
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 99604.077
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 46670.925
#
# Scenario 2970:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 71451.446
# Investment in Stocks at Period 3: 101993.65
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 57038.701
#
# Scenario 2971:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81929.105
# Investment in Stocks at Period 3: 98033.468
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 49471.428
#
# Scenario 2972:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 67802.227
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 88082.966
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 32112.696
#
# Scenario 2973:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 75907.224
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 112451.97
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 79792.432
#
# Scenario 2974:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75182.392
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 110313.35
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 46186.632
#
# Scenario 2975:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76568.725
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102934.42
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58892.508
#
# Scenario 2976:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 77303.099
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 102367.96
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 53048.71
#
# Scenario 2977:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81239.166
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 94222.41
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 45681.518
#
# Scenario 2978:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 81579.808
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 95636.861
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59272.557
#
# Scenario 2979:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 69119.782
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 77313.849
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31854.418
#
# Scenario 2980:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 79803.951
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 119496.22
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 93800.083
#
# Scenario 2981:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 76518.45
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 114654.3
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 50837.636
#
# Scenario 2982:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 81891.751
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 103424.7
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60718.778
#
# Scenario 2983:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76728.679
# Investment in Stocks at Period 3: 112276.4
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 76376.199
#
# Scenario 2984:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 61560.238
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 89182.724
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 33468.028
#
# Scenario 2985:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 74632.951
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 103327.96
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 56807.124
#
# Scenario 2986:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 68438.983
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 99043.075
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 44551.957
#
# Scenario 2987:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 78841.443
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 103865.8
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 60855.893
#
# Scenario 2988:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 71094.389
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 81917.686
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 17907.861
#
# Scenario 2989:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 61447.006
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 77329.247
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 34910.604
#
# Scenario 2990:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 66874.316
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 100159.93
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59617.02
#
# Scenario 2991:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 71178.692
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 104224.35
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 58069.15
#
# Scenario 2992:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 73077.393
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 84187.649
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 40482.493
#
# Scenario 2993:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 64404.197
# Investment in Stocks at Period 3: 90794.254
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 48515.58
#
# Scenario 2994:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 69899.158
# Investment in Stocks at Period 3: 95352.915
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 31226.828
#
# Scenario 2995:
# Investment in Stocks at Period 1: 55000.0
# Investment in Bonds at Period 1: 0.0
# Investment in Stocks at Period 2: 81681.077
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 85651.35
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 37284.773
#
# Scenario 2996:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 76926.569
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 93453.684
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 50423.256
#
# Scenario 2997:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 71386.246
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 104235.34
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 74610.812
#
# Scenario 2998:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 0.0
# Investment in Bonds at Period 2: 75428.842
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 93040.616
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 59042.65
#
# Scenario 2999:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 80524.977
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 101587.82
# Investment in Bonds at Period 3: 0.0
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 62426.682
#
# Scenario 3000:
# Investment in Stocks at Period 1: 0.0
# Investment in Bonds at Period 1: 55000.0
# Investment in Stocks at Period 2: 69996.107
# Investment in Bonds at Period 2: 0.0
# Investment in Stocks at Period 3: 0.0
# Investment in Bonds at Period 3: 90224.029
# Wealth after 15 years: 0.0
# Borrowing after 15 years: 49863.486
#
# Total Expected Utility: 512.2878847213738
# Time duration for 3000 scenarios is: 2.5424468000000005
